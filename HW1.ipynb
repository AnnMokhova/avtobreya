# %% [markdown]
# # Определение языка и VK API

# %% [markdown]
# В данном задании вам нужно будет:
#
# * используя API Вконтакте, скачать комментарии к первым ста постам из пяти сообществ
# * натренировать модель распознавания языков на статьях из Википедии.
# * распознать язык всех комментариев, где в тексте есть 10 и более символов, и построить статистику

# %% [markdown]
# ## VK API

# %% [markdown]
# Для подключения к ВКонтакте мы будем использовать VK API. Здесь есть документация к этой библиотеке https://vk-api.readthedocs.io/en/latest/

# %%
#!pip(3) install vk_api

# %%
import vk_api

# здесь нужно ввести данные своего аккаунта
# когда будете сдавать, не забудьте убрать эти две строчки из ноутбука
user = '' # вставьте сюда свой номер телефона
password = '' # вставьте сюда свой пароль

# авторизация
vk_session = vk_api.VkApi(login=user, password=password)
vk_session.auth()

vk = vk_session.get_api() # объект с API

# %% [markdown]
# Получить записи со страницы можно с помощью метода `wall.get`. Он принимает параметр `domain` — короткое имя пользователя или сообщества — и `count` — количество записей, которое вы хотите получить (максимум — 100). По Список методов для работы со стенами: https://vk.com/dev/wall

# %% [markdown]
# Например, вот так можно получить последние две записи с вот этой страницы https://vk.com/futureisnow. Выдача представляет собой словарь, в котором в поле `items` записан список словарей, содержащий информацию о каждой из записи.

# %%
vk.wall.get(domain="futureisnow", count=2)
# Out:
# {'count': 8196,
#  'items': [{'id': 250402,
#    'from_id': -111587102,
#    'owner_id': -111587102,
#    'date': 1569742419,
#    'marked_as_ads': 0,
#    'post_type': 'post',
#    'text': '',
#    'signer_id': 6087960,
#    'attachments': [{'type': 'photo',
#      'photo': {'id': 457288623,
#       'album_id': -7,
#       'owner_id': -111587102,
#       'user_id': 100,
#       'sizes': [{'type': 'm',
#         'url': 'https://sun1-92.userapi.com/c851420/v851420381/1cee23/aOnqIXBKMP4.jpg',
#         'width': 97,
#         'height': 130},
#        {'type': 'o',
#         'url': 'https://sun1-90.userapi.com/c851420/v851420381/1cee28/XW6u_nZhoY8.jpg',
#         'width': 130,
#         'height': 173},
#        {'type': 'p',
#         'url': 'https://sun1-92.userapi.com/c851420/v851420381/1cee29/Z_hh1DQSde4.jpg',
#         'width': 200,
#         'height': 267},
#        {'type': 'q',
#         'url': 'https://sun1-14.userapi.com/c851420/v851420381/1cee2a/eOOnk5aWJxM.jpg',
#         'width': 320,
#         'height': 427},
#        {'type': 'r',
#         'url': 'https://sun1-26.userapi.com/c851420/v851420381/1cee2b/fSs3iWDyooY.jpg',
#         'width': 510,
#         'height': 680},
#        {'type': 's',
#         'url': 'https://sun1-88.userapi.com/c851420/v851420381/1cee22/xXg539KUDJc.jpg',
#         'width': 56,
#         'height': 75},
#        {'type': 'w',
#         'url': 'https://sun1-93.userapi.com/c851420/v851420381/1cee27/hJDij2AXy5g.jpg',
#         'width': 960,
#         'height': 1280},
#        {'type': 'x',
#         'url': 'https://sun1-20.userapi.com/c851420/v851420381/1cee24/Ab-Pf0JySIk.jpg',
#         'width': 453,
#         'height': 604},
#        {'type': 'y',
#         'url': 'https://sun1-30.userapi.com/c851420/v851420381/1cee25/clYTCxU2-Jg.jpg',
#         'width': 605,
#         'height': 807},
#        {'type': 'z',
#         'url': 'https://sun1-16.userapi.com/c851420/v851420381/1cee26/FQTEW-BA_Zw.jpg',
#         'width': 810,
#         'height': 1080}],
#       'text': '',
#       'date': 1569730032,
#       'post_id': 250384,
#       'access_key': '6dc3df32a4d8fc5c3c'}}],
#    'post_source': {'type': 'api'},
#    'comments': {'count': 9, 'can_post': 1, 'groups_can_post': True},
#    'likes': {'count': 122, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#    'reposts': {'count': 0, 'user_reposted': 0},
#    'views': {'count': 11608},
#    'is_favorite': False},
#   {'id': 250278,
#    'from_id': -111587102,
#    'owner_id': -111587102,
#    'date': 1569693781,
#    'marked_as_ads': 0,
#    'post_type': 'post',
#    'text': '',
#    'signer_id': 66137348,
#    'attachments': [{'type': 'photo',
#      'photo': {'id': 457288585,
#       'album_id': -7,
#       'owner_id': -111587102,
#       'user_id': 100,
#       'sizes': [{'type': 'm',
#         'url': 'https://sun1-26.userapi.com/c855220/v855220775/107a1a/t47yxhYop50.jpg',
#         'width': 60,
#         'height': 130},
#        {'type': 'o',
#         'url': 'https://sun1-89.userapi.com/c855220/v855220775/107a1f/i-_ScEx1I5w.jpg',
#         'width': 130,
#         'height': 282},
#        {'type': 'p',
#         'url': 'https://sun1-83.userapi.com/c855220/v855220775/107a20/zLrOpEuL10g.jpg',
#         'width': 200,
#         'height': 435},
#        {'type': 'q',
#         'url': 'https://sun1-26.userapi.com/c855220/v855220775/107a21/TZv8SdwijTM.jpg',
#         'width': 320,
#         'height': 694},
#        {'type': 'r',
#         'url': 'https://sun1-18.userapi.com/c855220/v855220775/107a22/NuB2APCd_Yc.jpg',
#         'width': 510,
#         'height': 900},
#        {'type': 's',
#         'url': 'https://sun1-85.userapi.com/c855220/v855220775/107a19/3rEghlcI2d0.jpg',
#         'width': 35,
#         'height': 75},
#        {'type': 'w',
#         'url': 'https://sun1-87.userapi.com/c855220/v855220775/107a1e/VTJtsQcDztk.jpg',
#         'width': 540,
#         'height': 1170},
#        {'type': 'x',
#         'url': 'https://sun1-88.userapi.com/c855220/v855220775/107a1b/dUyJwzJmMHc.jpg',
#         'width': 278,
#         'height': 604},
#        {'type': 'y',
#         'url': 'https://sun1-84.userapi.com/c855220/v855220775/107a1c/sjvja8fzHQs.jpg',
#         'width': 372,
#         'height': 807},
#        {'type': 'z',
#         'url': 'https://sun1-85.userapi.com/c855220/v855220775/107a1d/ucBgHr6vT5k.jpg',
#         'width': 498,
#         'height': 1080}],
#       'text': '',
#       'date': 1569678101,
#       'access_key': '7bc7e19e659d6b939c'}},
#     {'type': 'photo',
#      'photo': {'id': 457288586,
#       'album_id': -7,
#       'owner_id': -111587102,
#       'user_id': 100,
#       'sizes': [{'type': 'm',
#         'url': 'https://sun1-23.userapi.com/c854228/v854228775/106b47/CDuWox50pRE.jpg',
#         'width': 130,
#         'height': 97},
#        {'type': 'o',
#         'url': 'https://sun1-91.userapi.com/c854228/v854228775/106b4b/daYCcuKaX-E.jpg',
#         'width': 130,
#         'height': 97},
#        {'type': 'p',
#         'url': 'https://sun1-24.userapi.com/c854228/v854228775/106b4c/N4jnylnn2bQ.jpg',
#         'width': 200,
#         'height': 149},
#        {'type': 'q',
#         'url': 'https://sun1-85.userapi.com/c854228/v854228775/106b4d/6RWf3sHeH94.jpg',
#         'width': 320,
#         'height': 239},
#        {'type': 'r',
#         'url': 'https://sun1-21.userapi.com/c854228/v854228775/106b4e/GmZehtpUfJg.jpg',
#         'width': 510,
#         'height': 380},
#        {'type': 's',
#         'url': 'https://sun1-25.userapi.com/c854228/v854228775/106b46/1aq6iSGEtGE.jpg',
#         'width': 75,
#         'height': 56},
#        {'type': 'x',
#         'url': 'https://sun1-88.userapi.com/c854228/v854228775/106b48/xzfT-n9KR34.jpg',
#         'width': 604,
#         'height': 451},
#        {'type': 'y',
#         'url': 'https://sun1-86.userapi.com/c854228/v854228775/106b49/AlKJpSYUazE.jpg',
#         'width': 807,
#         'height': 602},
#        {'type': 'z',
#         'url': 'https://sun1-14.userapi.com/c854228/v854228775/106b4a/yhK5v1lUFko.jpg',
#         'width': 1080,
#         'height': 805}],
#       'text': '',
#       'date': 1569678101,
#       'access_key': '990aba88e7d8b060c4'}}],
#    'post_source': {'type': 'vk'},
#    'comments': {'count': 54, 'can_post': 1, 'groups_can_post': True},
#    'likes': {'count': 953, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#    'reposts': {'count': 29, 'user_reposted': 0},
#    'views': {'count': 51711},
#    'is_favorite': False}]}

# %% [markdown]
# С помощью метода `groups.getById` можно получить информацию о сообществе, в том числе его id.

# %%
vk.groups.getById(group_ids="futureisnow")
# Out:
# [{'id': 111587102,
#   'name': 'киберпанк, который мы заслужили',
#   'screen_name': 'futureisnow',
#   'is_closed': 0,
#   'type': 'page',
#   'is_admin': 0,
#   'is_member': 0,
#   'is_advertiser': 0,
#   'photo_50': 'https://sun1-29.userapi.com/c845124/v845124938/4b879/-EzOFg-vjTg.jpg?ava=1',
#   'photo_100': 'https://sun1-14.userapi.com/c845124/v845124938/4b878/Lr9NW4jLxOU.jpg?ava=1',
#   'photo_200': 'https://sun1-85.userapi.com/c845124/v845124938/4b877/dqfgJ42Ir5E.jpg?ava=1'}]

# %% [markdown]
# Скачайте информацию о последних ста записях в следующих пабликах: https://vk.com/futureisnow, https://vk.com/eternalclassic, https://vk.com/ukrlit_memes, https://vk.com/ukrainer_net, https://vk.com/amanzohel, https://vk.com/barg_kurumk_culture

# %%
# список domain'ов, чтобы вам не копировать их самими :)
publics = ["futureisnow",
           "eternalclassic",
           "ukrlit_memes",
           "ukrainer_net",
           "amanzohel",
           "barg_kurumk_culture"]

# %%
items = {} # ключи — это паблики
posts = [] # все скачанные посты

for i in publics:
    name = str(i)
    data = vk.wall.get(domain=name, count=100)
    data = data['items']
    posts += data
    items[name] = data
    
#print(items)
# Out:
# {'futureisnow': [{'id': 250402, 'from_id': -111587102, 'owner_id': -111587102, 'date': 1569742419, 'marked_as_ads': 0, 'post_type': 'post', 'text': '', 'signer_id': 6087960, 'attachments': [{'type': 'photo', 'photo': {'id': 457288623, 'album_id': -7, 'owner_id': -111587102, 'user_id': 100, 'sizes': [{'type': 'm', 'url': 'https://sun1-92.userapi.com/c851420/v851420381/1cee23/aOnqIXBKMP4.jpg', 'width': 97, 'height': 130}, {'type': 'o', 'url': 'https://sun1-90.userapi.com/c851420/v851420381/1cee28/XW6u_nZhoY8.jpg', 'width': 130, 'height': 173}, {'type': 'p', 'url': 'https://sun1-92.userapi.com/c851420/v851420381/1cee29/Z_hh1DQSde4.jpg', 'width': 200, 'height': 267}, {'type': 'q', 'url': 'https://sun1-14.userapi.com/c851420/v851420381/1cee2a/eOOnk5aWJxM.jpg', 'width': 320, 'height': 427}, {'type': 'r', 'url': 'https://sun1-26.userapi.com/c851420/v851420381/1cee2b/fSs3iWDyooY.jpg', 'width': 510, 'height': 680}, {'type': 's', 'url': 'https://sun1-88.userapi.com/c851420/v851420381/1cee22/xXg539KUDJc.jpg', 'width': 56, 'height': 75}, {'type': 'w', 'url': 'https://sun1-93.userapi.com/c851420/v851420381/1cee27/hJDij2AXy5g.jpg', 'width': 960, 'height': 1280}, {'type': 'x', 'url': 'https://sun1-20.userapi.com/c851420/v851420381/1cee24/Ab-Pf0JySIk.jpg', 'width': 453, 'height': 604}, {'type': 'y', 'url': 'https://sun1-30.userapi.com/c851420/v851420381/1cee25/clYTCxU2-Jg.jpg', 'width': 605, 'height': 807}, {'type': 'z', 'url': 'https://sun1-16.userapi.com/c851420/v851420381/1cee26/FQTEW-BA_Zw.jpg', 'width': 810, 'height': 1080}], 'text': '', 'date': 1569730032, 'post_id': 250384, 'access_key': '6dc3df32a4d8fc5c3c'}}], 'post_source': {'type': 'api'}, 'comments': {'count': 9, 'can_post': 1, 'groups_can_post': True}, 'likes': {'count': 122, 'user_likes': 0, 'can_like': 1, 'can_publish': 1}, 'reposts': {'count': 0, 'user_reposted': 0}, 'views': {'count': 11662}, 'is_favorite': False}, {'id': 250278, 'from_id': -111587102, 'owner_id': -111587102, 'date': 1569693781, 'marked_as_ads': 0, 'post_type': 'post', 'text': '', 'signer_id': 66137348, 'attachments': [{'type': 'photo', 'photo': {'id': 457288585, 'album_id': -7, 'owner_id': -111587102, 'user_id': 100, 'sizes': [{'type': 'm', 'url': 'https://sun1-26.userapi.com/c855220/v855220775/107a1a/t47yxhYop50.jpg', 'width': 60, 'height': 130}, {'type': 'o', 'url': 'https://sun1-89.userapi.com/c855220/v855220775/107a1f/i-_ScEx1I5w.jpg', 'width': 130, 'height': 282}, {'type': 'p', 'url': 'https://sun1-83.userapi.com/c855220/v855220775/107a20/zLrOpEuL10g.jpg', 'width': 200, 'height': 435}, {'type': 'q', 'url': 'https://sun1-26.userapi.com/c855220/v855220775/107a21/TZv8SdwijTM.jpg', 'width': 320, 'height': 694}, {'type': 'r', 'url': 'https://sun1-18.userapi.com/c855220/v855220775/107a22/NuB2APCd_Yc.jpg', 'width': 510, 'height': 900}, {'type': 's', 'url': 'https://sun1-85.userapi.com/c855220/v855220775/107a19/3rEghlcI2d0.jpg', 'width': 35, 'height': 75}, {'type': 'w', 'url': 'https://sun1-87.userapi.com/c855220/v855220775/107a1e/VTJtsQcDztk.jpg', 'width': 540, 'height': 1170}, {'type': 'x', 'url': 'https://sun1-88.userapi.com/c855220/v855220775/107a1b/dUyJwzJmMHc.jpg', 'width': 278, 'height': 604}, {'type': 'y', 'url': 'https://sun1-84.userapi.com/c855220/v855220775/107a1c/sjvja8fzHQs.jpg', 'width': 372, 'height': 807}, {'type': 'z', 'url': 'https://sun1-85.userapi.com/c855220/v855220775/107a1d/ucBgHr6vT5k.jpg', 'width': 498, 'height': 1080}], 'text': '', 'date': 1569678101, 'access_key': '7bc7e19e659d6b939c'}}, {'type': 'photo', 'photo': {'id': 457288586, 'album_id': -7, 'owner_id': -111587102, 'user_id': 100, 'sizes': [{'type': 'm', 'url': 'https://sun1-23.userapi.com/c854228/v854228775/106b47/CDuWox50pRE.jpg', 'width': 130, 'height': 97}, {'type': 'o', 'url': 'https://sun1-91.userapi.com/c854228/v854228775/106b4b/daYCcuKaX-E.jpg', 'width': 130, 'height': 97}, {'type': 'p', 'url': 'https://sun1-24.userapi.com/c854228/v854228775/106b4c/N4jnylnn2bQ.jpg', 'width': 200, 'height': 149}, {'type': 'q', 'url': 'htt ...

# %% [markdown]
# Найдите в документации (https://vk.com/dev/wall) метод для получения комментариев и получите первые сто комментариев каждого поста из выборки для каждого паблика.

# %%
corpora = {}

futureisnow = []  # все комментарии к 100 постам паблика futureisnow
eternalclassic = []  # все комментарии к 100 постам паблика eternalclassic
ukrlit_memes = []  # все комментарии к 100 постам паблика ukrlit_memes
ukrainer_net = []  # все комментарии к 100 постам паблика ukrainer_net
amanzohel = []  # все комментарии к 100 постам паблика amanzohel
barg_kurumk_culture = []  # все комментарии к 100 постам паблика barg_kurumk_culture

for post in posts:
    post_id = post['id']
    owner_id = post['owner_id']
    comments = vk.wall.getComments(owner_id=owner_id, 
                                   post_id=post_id, count=100)
    comments = comments['items']
    for comment in comments:
        if 'deleted' in comment:
                continue
        if len(comment['text']) > 10:
            text = comment['text']
        if owner_id == -111587102:
            futureisnow.append(text) 
        if owner_id == -129440544:
            eternalclassic.append(text) 
        if owner_id == -131348832:
            ukrlit_memes.append(text)
        if owner_id == -5164516:
            ukrainer_net.append(text)
        if owner_id == -66347916:
            amanzohel.append(text)
        if owner_id == -95189895:
            barg_kurumk_culture.append(text)
        
com = []
com.append(futureisnow)
com.append(eternalclassic)
com.append(ukrlit_memes)
com.append(ukrainer_net)
com.append(amanzohel)
com.append(barg_kurumk_culture)

corpora = dict(zip(publics, com))

#print(corpora)
# Out:
# {'futureisnow': ['Оплата: 0.01руб. за ролик', 'QR коды надо ставить на ссылки. Незачёт', 'Спортмастер Спортмастер Спортмастер....', 'очень удобно!', 'Ох уж этот Спортмастер, а вроде серьезная компания', 'Носки. Экспресс курс', 'Пфф, это самый настоящий киберпанк.\n\nМучайся, если тебе не хватает ума воспользоваться системой распознавания текста. \n\nПару ошибок исправил и готово: http://wtsmgksm.local/view_doc.html?mode=library_material&doc_id=6695708558797008529&object_id=6707164789886686922', 'Морг, ноут и котик. Шикарно', 'Только за шасси дорого же, ну', 'Приезжайте, забирайте', 'High tech, low life. Все по канону', 'Ну нормально, гаражный сервер.', 'дроп с сисадмина?', 'Это настолько гротескно, что абсолютно гениально. Ночь, сервак, морг и кошачья жопа. Я бы на стену повесил', 'Господа, кто шарит в железе, гляньте пожалуйста. Ценник сильно загнул? Посмотри объявление "Компьютер, монитор. Полный комплект" на Авито:  \n \nhttps://www.avito.ru/nizhnevartovsk/nastolnye_kompyutery/kompyuter_monitor._polnyy_komplekt_1793435939?utm_campaign=native&utm_medium=item_page_ios&utm_source=soc_sharing', 'Ночь\nМорг\nСервак\nКотейка\nБессмысленный и тусклый свет...', 'На этой фотографии идеально всё', 'Этот сервак наверное похоронный сайт держал', 'Этот сервак наверное похоронный сайт держал', 'Кот нашел на помойке сервак и решил загнать его на авито?', 'Кот нашел на помойке сервак и решил загнать его на авито?', 'Ну логично что продает\nЕму в морге он уже не понадобится', 'Фото оставило вопросов больше чем дало ответов.', 'Программисты с больничнки скидываю не оборудование', 'Так много вопросов и так мало ответов...', 'Так много вопросов и так мало ответов...', 'Щас еще вишневая девятка есть', 'Щас еще вишневая девятка есть', 'Щас еще вишневая девятка есть', 'Щас еще вишневая девятка есть', 'Это Виллалобос?', 'Без неё ему в рашке не выжить... каким бы Уиком он не был', 'Без неё ему в рашке не выжить... каким бы Уиком он не был', 'Без неё ему в рашке не выжить... каким бы Уиком он не был', 'Такой, ещё не заслужили.', 'Такой, ещё не заслужили.', 'Кибербалтика', 'Кибербалтика', 'Кибербалтика', 'Ретрофутуризм с милицией', 'Ретрофутуризм с милицией', 'Ого, QR код, надо же, как необычно \nНикогда его не видели и вот опять', 'Сканируешь код, переходишь по ссылке\nА там армяне в нарды играют', 'Кто-нибудь, откройте его', '>qr код в основном используется для рекламы и продвижения товаров\n>ОГО ВЫ ВИДЕЛИ КЬЮЭРКОД НА ЧАЕ', '>qr код в основном используется для рекламы и продвижения товаров\n>ОГО ВЫ ВИДЕЛИ КЬЮЭРКОД НА ЧАЕ', 'Баян. Это давно есть.', 'кто первый сделает на туалетной бумаге, тот молодец', 'www.hyleys.ru', 'https://vk.com/video-30316056_456302132', 'Сканируешь его а там', 'кажется пришло время отписаться от очередной группы)', 'о я пила такой .российский производитель кста', 'Да че с вами стало? шо за шлак? блет', '>выходишь из комы спустя 15 лет\n>пьешь чай, карандашом отгадываешь правильный путь в лабиринте\n>не понимаешь, о чем вообще пишут люди сверху', 'Что-то в этом есть.', 'Именно так работает технология омолаживания', 'Именно так работает технология омолаживания', 'ArИana GranDe', 'Отличное приложение, всем советую. (Нет)', 'ТОДИДОДОДО!!!!!!1111', 'что за приложение?', 'что за приложение?', 'Прояснилось 🤣', 'Это же Ельцин! Ну, по крайней мере, в детстве мне так казалось.', 'ОТКУДА ОРИГИНАЛ? ЧТО ЭТО ЗА ЗНАК?', 'Это смешно по вашему ?', 'Да и **й с этим льдом', 'И на голове его куча дерьма в форме жабы', 'И на голове его куча дерьма в форме жабы', 'Ленин хорошо смотрится', 'Ленин хорошо смотрится', 'GJ! Великолепно.', 'Зато не посудомойка!', 'Когда вытащил весь хлам из ящиков и собрал его в одном месте', 'Уверовал прям', 'Долго не мог понять че это за игра', 'Долго не мог понять че это за игра', 'И в чём тут киберпанк?', 'И в чём тут киберпанк?', 'Она ведь сильно блестит под ультраоранжевыми украшениями и световыми штучками? Иначе к чему все это.', 'я сначала подумал что это новый скрин киберпунка77', 'я сначала подумал что это но ...

# %% [markdown]
# **Задание со звездочкой:** вы могли заметить, что если обращаться к каждому посту отдельно, то все занимает довольно продолжительное время (около пяти минут). Найдите в документации vk_api способ сделать это быстрее.

# %%
#corpora = {}

# %% [markdown]
# ## Тренировка моделей

# %% [markdown]
# В наших комментариях встречались русский, украинский, английский и бурятский.

# %%
langs = {'ru', 'uk', 'en', 'bxr'}

# %%
from collections import Counter

import nltk
import wikipedia

# %%
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\vital\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %% [markdown]
# Скачайте документы, на которых вы будете обучать свои модели. Для наших целей хорошо иметь для каждого языка корпус размером около 50 статей.

# %%
# найдите нужный код, не вставляйте лишний (!)
def get_texts_for_lang(lang, n=10):
    wiki_content = []
    wikipedia.set_lang(lang)
    pages = wikipedia.random(n)
    for page_name in pages:
        try:
            page = wikipedia.page(page_name)
            wiki_content.append("%s\n%s" % (page.title, page.content.replace('=', '')))
        except wikipedia.exceptions.WikipediaException:
            print("Skip %s" % page_name)
    return wiki_content

# %%
wiki_texts = {}
for lang in langs:
    wiki_texts[lang] = get_texts_for_lang(lang, 50)
    print(lang, len(wiki_texts[lang]))
# Out:
# c:\users\vital\appdata\local\programs\python\python37-32\lib\site-packages\wikipedia\wikipedia.py:389: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 389 of the file c:\users\vital\appdata\local\programs\python\python37-32\lib\site-packages\wikipedia\wikipedia.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#
#   lis = BeautifulSoup(html).find_all('li')
# Skip Sapporo (disambiguation)
# Skip Holiday Soul
# Skip John Bell House
# Skip The Worker
# Skip Laia
# en 45
# Skip Глушица
# Skip Циммерманы
# Skip Красное Городище
# ru 47
# bxr 50
# Skip Космополіт (значення)
# Skip Комета (значення)
# Skip Федорівське
# Skip Баранувка
# uk 46

# %% [markdown]
# Сделайте определялку на частотах слов.

# %%
# найдите нужный код, не вставляйте лишний (!)

def collect_freqlist(wiki_pages, max_len=100):
    freqlist = Counter()
    # не забудем про токенизацию - nltk.word_tokenize
    for text in wiki_pages:
        for word in nltk.word_tokenize(text.lower()):
            if word.isalpha():
                freqlist[word] += 1
    return dict(freqlist.most_common(max_len))

# %%
freq_lists = {}
for lang in langs:
    freq_lists[lang] = collect_freqlist(wiki_texts[lang])

# %%
def simple_lang_detect(freq_lists, text):
    counts = Counter()
    for lang, freq_list in freq_lists.items():
        freq_list = Counter(freq_list)
        for word in nltk.word_tokenize(text):
            counts[lang] += int(freq_list[word] > 0)
    return counts.most_common()

# %% [markdown]
# Сделайте определялку на символьных энграммах.

# %%
# найдите нужный код, не вставляйте лишний (!)

from sklearn import feature_extraction

vectorizer = feature_extraction.text.TfidfVectorizer(ngram_range=(1, 5), analyzer='char')
vectorizer.fit(wiki_texts['ru'])
for item in vectorizer.get_feature_names()[:100]:
    print(item)
# Out:
# .
#
# .
#
#
# .
# с
#
# .
# со
#
# 1
#
# 1
#
# 1 о
#
# 1 ок
#
# 1 ф
#
# 1 фе
#
# 1 я
#
# 1 ян
#
# 1-
#
# 1-й
#
# 1-й
#
# 1.
#
# 1.
#
# 1. п
#
# 10
#
# 10
#
# 10 м
#
# 11
#
# 11a
#
# 11a5
#
# 11а
#
# 11а5
#
# 13
#
# 13:
#
# 13:
#
# 14
#
# 14
#
# 14 и
#
# 16
#
# 16
#
# 16 и
#
# 17
#
# 17
#
# 17 д
#
# 17 и
#
# 18
#
# 18
#
# 18 а
#
# 18 я
#
# 19
#
# 19
#
# 19 а
#
# 19 д
#
# 192
#
# 1923
#
# 1925
#
# 1928
#
# 193
#
# 1931
#
# 1933
#
# 1936
#
# 1937
#
# 1938
#
# 194
#
# 1940
#
# 1942
#
# 1943
#
# 1947
#
# 195
#
# 1953
#
# 1956
#
# 1957
#
# 1958
#
# 1959
#
# 196
#
# 1960
#
# 1962
#
# 1964
#
# 1966
#
# 1969
#
# 197
#
# 1970
#
# 1972
#
# 1974
#
# 1975
#
# 199
#
# 1995
#
# 2
#
# 2)
#
# 2)
#
# 2) п
#
# 2.
#
# 2.
#
# 2. п
#
# 20
#
# 20
#
# 20 о
#
# 22
#
# 22
#
# 22 я
#
# 24
#
# 24
#
# 24 д
#
# 25
#
# 25

# %%
from sklearn import pipeline
from sklearn import naive_bayes
import numpy as np

# %pylab inline
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Populating the interactive namespace from numpy and matplotlib
# c:\users\vital\appdata\local\programs\python\python37-32\lib\site-packages\IPython\core\magics\pylab.py:160: UserWarning: pylab import has clobbered these variables: ['text']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
clf = pipeline.Pipeline([
    ('vctr', feature_extraction.text.TfidfVectorizer(ngram_range=(1, 2), analyzer='char')),
    ('clf', naive_bayes.MultinomialNB())
])

# %%
all_texts = []
lang_indices = []
for lang in wiki_texts:
    all_texts.extend(wiki_texts[lang])
    lang_indices.extend([lang]*len(wiki_texts[lang]))

# %%
# Обучаем классификатор
clf.fit(np.array(all_texts), np.array(lang_indices))
# Out:
# Pipeline(memory=None,
#          steps=[('vctr',
#                  TfidfVectorizer(analyzer='char', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.float64'>,
#                                  encoding='utf-8', input='content',
#                                  lowercase=True, max_df=1.0, max_features=None,
#                                  min_df=1, ngram_range=(1, 2), norm='l2',
#                                  preprocessor=None, smooth_idf=True,
#                                  stop_words=None, strip_accents=None,
#                                  sublinear_tf=False,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=None, use_idf=True,
#                                  vocabulary=None)),
#                 ('clf',
#                  MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))],
#          verbose=False)

# %% [markdown]
# # Определение языка

# %% [markdown]
# Определите язык каждого комментария в каждом паблике с помощью определялки на частотах слов и покажите доли языков среди комментариев для каждого паблика.

# %%
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# %%
lang_detects_freqs = {}

for key, value in corpora.items():
    public = key
    ru = 0
    en = 0
    bxr = 0
    uk = 0
    NA = 0 
    for i in value:
       # print(i)
        text = str(i)
        lang_detects_freqs = dict(simple_lang_detect(freq_lists, text))
       # print(lang_detects_freqs)
        top = {c: lang_detects_freqs[c] for c in 
               lang_detects_freqs if lang_detects_freqs[c] > 0 and len(c) > 0}
        top = (sorted(top.items(), key=lambda x: x[1], reverse=True))[:1]
        top = dict(top)
        if len(top) == 0:
            NA += 1
        for key in top.keys():
            if key == 'ru':
                ru +=1
            if key == 'en':
                en +=1
            if key == 'uk':
                uk +=1
            if key == 'bxr':
                bxr +=1
    
    languages = ['NA', 'ru', 'en', 'uk', 'bxr']
    nums = [NA, ru, en, uk, bxr]
    lang_detects_freqs = dict(zip(languages, nums))
    print('Доли языков среди комментариев для паблика', public)
    print(lang_detects_freqs)
    Y = [c[1] for c in sorted(
        lang_detects_freqs.items(), key=lambda x: x[0], reverse=False
        )
        ]
    X = sorted([l for l in lang_detects_freqs])
    plt.bar(X, Y, color='aqua')
    plt.show()
    
#    texts = str(value)
#    lang_detects_freqs = dict(simple_lang_detect(freq_lists, texts))
#    #print(lang_detects_freqs)
#    print('Доли языков среди комментариев для паблика', key)
#    print(lang_detects_freqs)
#    Y = [c[1] for c in sorted(
#        lang_detects_freqs.items(), key=lambda x: x[0], reverse=False
#        )
#        ]
#    X = sorted([l for l in lang_detects_freqs])
#    plt.bar(X, Y, color='aqua')
#    plt.show()
# Out:
# Доли языков среди комментариев для паблика futureisnow
# {'NA': 560, 'ru': 946, 'en': 17, 'uk': 1, 'bxr': 0}
# Доли языков среди комментариев для паблика eternalclassic
# {'NA': 600, 'ru': 0, 'en': 920, 'uk': 0, 'bxr': 0}
# Доли языков среди комментариев для паблика ukrlit_memes
# {'NA': 137, 'ru': 96, 'en': 5, 'uk': 96, 'bxr': 0}
# Доли языков среди комментариев для паблика ukrainer_net
# {'NA': 95, 'ru': 63, 'en': 0, 'uk': 84, 'bxr': 0}
# Доли языков среди комментариев для паблика amanzohel
# {'NA': 387, 'ru': 36, 'en': 0, 'uk': 1, 'bxr': 20}
# Доли языков среди комментариев для паблика barg_kurumk_culture
# {'NA': 139, 'ru': 118, 'en': 0, 'uk': 1, 'bxr': 24}

# %% [markdown]
# Сделайте то же самое для определителя на символьных энграммах.

# %%
lang_detects_ngrams = {}

for key, value in corpora.items():
    public = key
    texts = value
    results = clf.predict(texts)
    ru = 0
    en = 0
    uk = 0
    bxr = 0
    for i in results:
        if i == 'ru':
            ru += 1
        if i == 'en':
            en += 1
        if i == 'uk':
            uk  += 1
        if i == 'bxr':
            bxr += 1
            
    lang_detects_ngrams['bxr'] = bxr
    lang_detects_ngrams['en'] = en
    lang_detects_ngrams['ru'] = ru
    lang_detects_ngrams['uk'] = uk
     
    print('Доли языков среди комментариев для паблика', key)
    print(lang_detects_ngrams)
    Y = [c[1] for c in sorted(
        lang_detects_ngrams.items(), key=lambda x: x[0], reverse=False
        )
        ]
    X = sorted([l for l in lang_detects_ngrams])
    plt.bar(X, Y, color='aqua')
    plt.show()
# Out:
# Доли языков среди комментариев для паблика futureisnow
# {'bxr': 29, 'en': 65, 'ru': 1425, 'uk': 5}
# Доли языков среди комментариев для паблика eternalclassic
# {'bxr': 0, 'en': 1516, 'ru': 4, 'uk': 0}
# Доли языков среди комментариев для паблика ukrlit_memes
# {'bxr': 9, 'en': 8, 'ru': 141, 'uk': 176}
# Доли языков среди комментариев для паблика ukrainer_net
# {'bxr': 13, 'en': 6, 'ru': 74, 'uk': 149}
# Доли языков среди комментариев для паблика amanzohel
# {'bxr': 387, 'en': 0, 'ru': 57, 'uk': 0}
# Доли языков среди комментариев для паблика barg_kurumk_culture
# {'bxr': 103, 'en': 1, 'ru': 177, 'uk': 1}

# %% [markdown]
# Обсудите работу каждого из классификаторов, обсудите ошибки, объясните разницу в результатах.

# %% [markdown]
# Классификатор на частотах слов часто не определяет язык комменатрия (при условии, что его длина больше 10 символов), для каждого паблика доля NA составляет большой процент от общего числа, но можно попробовать определить самый популярный язык комменатриев:
#
# для futureisnow -- русский;
#
# для eternalclassic -- английсикй;
#
# для ukrlit_memes -- русский и украинский;
#
# для ukrainer_net -- украинский;
#
# для amanzohel -- русский;
#
# для barg_kurumk_culture -- русский.
#
# Ошибки для последних двух пабликов - определен русский язык, вместо предполагаемого бурятского. Вероятно, классификатор не смог распознать комменатрии на бурятском, и в данном распределении они относятся к группе NA.
#
# Классификатор на н-граммах показывает более приближенный к реальности результат по определению самого популярного языка комментариев:
#
# для futureisnow -- русский;
#
# для eternalclassic -- английсикй;
#
# для ukrlit_memes -- украинский;
#
# для ukrainer_net -- украинский;
#
# для amanzohel -- бурятский;
#
# для barg_kurumk_culture -- русский (бурятский на втором месте).
#
# Разница в результатах может объясняться тем, что определение языка по последовательности символов является более чувствительным  методом для разных типов текстов. Использования частотного словаря иногда бывает недостаточно, например, как показывают результаты, даже в длинном коммментарии необязательно есть топ-слова языка (может состоять из имени собственного + редкой экспрессивно-оценочной лексики).
